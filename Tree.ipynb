# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('mount_drive.py', 'w') as f:
  f.write('''from google.colab import drive
drive.mount('/content/drive')''')
